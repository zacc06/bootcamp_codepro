# %%
#Ejercicio 1
diccionario_vacio={}
diccionario_vacio["nombre"]=input("Ingrese su nombre: ")
print(diccionario_vacio)
diccionario_vacio["edad"]=int(input("Ingrese su edad: "))
print(diccionario_vacio)
diccionario_vacio["sexo"]=telefono=(int(input("Ingrese su numero de telefono: ")))
print(diccionario_vacio)
diccionario_vacio[telefono]=input("Ingrese su correo electronico: ")
print(diccionario_vacio)
diccionario_vacio["correo"]=input("Ingrese su correo: ")
print(diccionario_vacio)
# Out:
# {'nombre': 'lucas'}
# {'nombre': 'lucas', 'edad': 19}
# {'nombre': 'lucas', 'edad': 19, 'sexo': 993305408}
# {'nombre': 'lucas', 'edad': 19, 'sexo': 993305408, 993305408: 'masculino'}
# {'nombre': 'lucas', 'edad': 19, 'sexo': 993305408, 993305408: 'masculino', 'correo': 'sonlucas2006@gmail.com'}

# %%
#Ejercicio 4
diccionario={}
while True:
    
    usuario=int(input("Que desea realizar?: 1=CREAR, 2=MODIFICAR, 3=ELIMINAR, Presione otra telca para salir"))
    
    if usuario==1:
        clave=input("Ingrese una clave: ")
        valor=input("Ingrese un valor: ")
        diccionario[clave]=valor
        print(diccionario)
    elif usuario==2:
        print(diccionario)
        diccionario[clave]=valor
        print(diccionario)
    elif usuario==3:
        del diccionario[clave]
        print(diccionario)
    else: 
        break
# Out:
# {'nombre': 'lucas'}

# %%
agenda_contactos={}
datos={}
def  mostrar():
    print(agenda_contactos)
    
def crear():
    while True:
        clave=input("Ingrese su nombre: ")
        nro_tel=input("Ingrese su numero de telefono: ")
        correo=input("Ingrese su corre electronico: ")
        valor1=nro_tel+correo
        agenda_contactos[clave]=valor1
        print(agenda_contactos)

crear()
