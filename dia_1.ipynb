# %%
#Ejerccicio de suma
print("Ejercicio de suma")
print("**************")
cantidad_de_manzanas=10
cantida_de_naranjas=8
cantidad_de_frutas=cantidad_de_manzanas+cantida_de_naranjas
print("La cantidad e frutas es: ",cantidad_de_frutas)
#Ejercicio de resta
print("Ejercicio de resta")
print("*************")
frutas_vendidas=6
frutas_restantes=cantidad_de_frutas-frutas_vendidas
print("La cantidad de frutas restantes son: ",frutas_restantes)
# Out:
# Ejercicio de suma
# **************
# La cantidad e frutas es:  18
# Ejercicio de resta
# *************
# La cantidad de frutas restantes son:  12

# %%
caramelos=int(input("Ingresa el total de caramelos"))
niños=int(input("Ingresa la cantidad de niños"))
reciben=caramelos//niños
sobran=caramelos%niños
print(reciben)
print(sobran)
# Out:
# 2
# 0

# %%
def supermercado():
    cliente=input("Ingrese el nombre del cliente")
    pedido=input("Ingrese el tipo de producto que va adquirir del supermercado")
    cant=int(input("Igrese la cantidad"))
    precio=int(input("Ingrese el precio"))
    
    total_precio=cant*precio
    
    print("El costo total del pedido de ",pedido," del cliente ",cliente," es ",total_precio)
    
supermercado()
supermercado()
supermercado()
# Out:
# El costo total del pedido de  Manzanas  del cliente  Lucas  es  18000

# %%
product=input("Ingrese el tipo de pizza: ")
size=input("Ingrese las porciones que va querer: ")
agregado=input("Ingresa un agregado: ")

def preparando_pedido(producto,tamaño,agre):
    print("Tu pizza de ",product," se esta preparando, con agregado de ",agregado)
    print("...")
    print("🍕Tu pizza estas lista para llevar🍕")

preparando_pedido(product,size,agregado)
# Out:
# Tu pizza de  napolitana  se esta preparando, con agregado de  extra queso
# ...
# 🍕Tu pizza estas lista para llevar🍕

# %%
impuesto=0.10

def calcular_impuesto():
    precio=int(input("Ingrese el precio: "))
    impuesto_global=precio*impuesto
    print("El impuesto global es: ",impuesto_global)

calcular_impuesto()
# Out:
# El impuesto global es:  700.0
